# %% [markdown]
# # Unsupervised Learning 2
#
# ## Lesson 3: Market Basket Analysis
#
# ### Part 1: Identifying the 'Small' Customers

# %%
import numpy as np
import pandas as pd

# %%
# Load in the datasets identified in the previous lesson as small customers
df = pd.read_csv("small_cust.csv")

# %%
# Display some simple information to get a big picture of the data
df.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0       12821      215          6     92.72
# 1       12823       75          5   1759.50
# 2       12829      337         11    293.00
# 3       12831      263          9    215.05
# 4       12833      146         24    417.38

# %%
df.describe()
# Out:
#          CustomerID      Recency    Frequency     Monetary
# count   1327.000000  1327.000000  1327.000000  1327.000000
# mean   15579.752826   163.141673    14.232856   284.255170
# std     1610.318755   101.540730    10.731013   261.069377
# min    12821.000000     2.000000     1.000000     3.750000
# 25%    14175.000000    68.000000     7.000000   142.130000
# 50%    15565.000000   160.000000    12.000000   223.850000
# 75%    16989.000000   250.000000    20.000000   344.520000
# max    18282.000000   363.000000    77.000000  4055.720000

# %%
df.shape
# Out:
# (1327, 4)

# %%
# Get the total number of transactions for these customers
sum(df.Frequency)
# Out:
# 18887

# %% [markdown]
# ### Part 2: Getting the transactions

# %%
# Read in the filtered transaction data since the RFM was generated from this
tr = pd.read_csv("OnlineRetail_Filtered.csv")
print(tr.shape)
# Out:
# (339702, 8)

# %%
tr[tr.Description == 'POSTAGE'].shape
# Out:
# (27, 8)

# %%
# Filter dataframe to keep only transactions from the small customers
tf_f = tr[tr['CustomerID'].isin(df.CustomerID)]

# %%
tf_f.shape # Validate that transaction count is the same
# Out:
# (18887, 8)

# %%
# These 2 features will be used to group the data.
# Description is used instead of StockID as it is human readable when we analyze the assoc rules later
tf_f['Description'] = tf_f['Description'].str.strip()
tf_f['InvoiceNo'] = tf_f['InvoiceNo'].astype(str)
# Out:
# C:\Users\dpramr\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\dpramr\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# The result should be 1 row per transaction. Each column is the quantiy purchased for that item
basket = (tf_f.groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))

#drop postage entries
basket.drop('POSTAGE', inplace=True, axis=1)

# %%
'POSTAGE' in (basket.columns)
# Out:
# False

# %%
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 538368                          0.0                         0.0
# 538369                          0.0                         0.0
# 538420                          0.0                         0.0
# 538470                          0.0                         0.0
# 538509                          0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 538368                             0.0                        0.0
# 538369                             0.0                        0.0
# 538420                             0.0                        0.0
# 538470                             0.0                        0.0
# 538509                             0.0                        0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 538368                                    0.0
# 538369                                    0.0
# 538420                                    0.0
# 538470                                    0.0
# 538509                                    0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 538368                                   0.0                            2.0
# 538369                                   0.0                            0.0
# 538420                                   0.0                            0.0
# 538470                                   0.0                            0.0
# 538509                                   0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 538368                                       1.0                          1.0
# 538369                                       0.0                          0.0
# 538420                                       0.0                          0.0
# 538470                                       0.0                          0.0
# 538509                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  ...  ZINC HEARTS PLANT POT HOLDER  \
# InvoiceNo                               ...
# 538368                             0.0  ...                           0.0
# 538369                             0.0  ...                           0.0
# 538420                             0.0  ...                           0.0
# 538470                             0.0  ...                           0.0
# 538509                             0.0  ...                           0.0
#
# Description  ZINC HERB GARDEN CONTAINER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 538368                              0.0                          0.0
# 538369                              0.0                          0.0
# 538420                              0.0                          0.0
# 538470                              0.0                          0.0
# 538509                              0.0                          0.0
#
# Description  ZINC STAR T-LIGHT HOLDER  ZINC SWEETHEART SOAP DISH  \
# InvoiceNo
# 538368                            0.0                        0.0
# 538369                            0.0                        0.0
# 538420                            0.0                        0.0
# 538470                            0.0                        0.0
# 538509                            0.0                        0.0
#
# Description  ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 538368                                    0.0                             0.0
# 538369                                    0.0                             0.0
# 538420                                    0.0                             0.0
# 538470                                    0.0                             0.0
# 538509                                    0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL  ZINC TOP  2 DOOR WOODEN SHELF  \
# InvoiceNo
# 538368                                   0.0                            0.0
# 538369                                   0.0                            0.0
# 538420                                   0.0                            0.0
# 538470                                   0.0                            0.0
# 538509                                   0.0                            0.0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 538368                                    0.0
# 538369                                    0.0
# 538420                                    0.0
# 538470                                    0.0
# 538509                                    0.0
#
# [5 rows x 2801 columns]

# %% [markdown]
# ### Part 3: Generating the Association Rules

# %%
# import libraries
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# We only need binary encoding for the assoc rules
basket_sets = basket.applymap(encode_units)

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.01, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#                        antecedents                      consequents  \
# 0   (PAINTED METAL PEARS ASSORTED)  (ASSORTED COLOUR BIRD ORNAMENT)
# 1  (ASSORTED COLOUR BIRD ORNAMENT)   (PAINTED METAL PEARS ASSORTED)
# 2   (BAKING SET 9 PIECE RETROSPOT)     (BAKING SET SPACEBOY DESIGN)
# 3     (BAKING SET SPACEBOY DESIGN)   (BAKING SET 9 PIECE RETROSPOT)
# 4    (BLUE HAPPY BIRTHDAY BUNTING)    (PINK HAPPY BIRTHDAY BUNTING)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.023729            0.050282  0.019209    0.809524  16.099518
# 1            0.050282            0.023729  0.019209    0.382022  16.099518
# 2            0.042373            0.019774  0.015819    0.373333  18.880000
# 3            0.019774            0.042373  0.015819    0.800000  18.880000
# 4            0.015254            0.014124  0.011299    0.740741  52.444444
#
#    leverage  conviction
# 0  0.018016    4.986017
# 1  0.018016    1.579784
# 2  0.014981    1.564190
# 3  0.014981    4.788136
# 4  0.011084    3.802663

# %%
rules[ (rules['lift'] >= 6) &
       (rules['confidence'] >= 0.8) ].sort_values(['lift','confidence'], ascending=False)
# Out:
#                                           antecedents  \
# 5                       (PINK HAPPY BIRTHDAY BUNTING)
# 38  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...
# 8                    (PINK REGENCY TEACUP AND SAUCER)
# 32  (REGENCY CAKESTAND 3 TIER, PINK REGENCY TEACUP...
# 0                      (PAINTED METAL PEARS ASSORTED)
#
#                           consequents  antecedent support  consequent support  \
# 5       (BLUE HAPPY BIRTHDAY BUNTING)            0.014124            0.015254
# 38  (GREEN REGENCY TEACUP AND SAUCER)            0.016384            0.031073
# 8   (GREEN REGENCY TEACUP AND SAUCER)            0.024294            0.031073
# 32  (GREEN REGENCY TEACUP AND SAUCER)            0.014689            0.031073
# 0     (ASSORTED COLOUR BIRD ORNAMENT)            0.023729            0.050282
#
#      support  confidence       lift  leverage  conviction
# 5   0.011299    0.800000  52.444444  0.011084    4.923729
# 38  0.014689    0.896552  28.852665  0.014180    9.366290
# 8   0.019774    0.813953  26.194503  0.019019    5.207980
# 32  0.011864    0.807692  25.993007  0.011408    5.038418
# 0   0.019209    0.809524  16.099518  0.018016    4.986017
